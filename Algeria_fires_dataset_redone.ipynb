# %% [markdown]
# <a href="https://colab.research.google.com/github/ezta91/Esther-Erommonsele/blob/main/Algeria_fires_dataset_redone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Algerian_forest_fires_dataset (1).csv')

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df[df['day'].isnull()]
# Out:
#      day month year Temperature   RH   Ws Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  NaN   NaN  NaN         NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#     Classes
# 122       NaN

# %%
df.iloc[120:130, :]
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 120                             29      9  2012           26   80   16    1.8
# 121                             30      9  2012           25   78   14    1.4
# 122                            NaN    NaN   NaN          NaN  NaN  NaN    NaN
# 123  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 124                            day  month  year  Temperature   RH   Ws  Rain
# 125                              1      6  2012           32   71   12    0.7
# 126                              2      6  2012           30   73   13      4
# 127                              3      6  2012           29   80   14      2
# 128                              4      6  2012           30   64   14      0
# 129                              5      6  2012           32   60   14    0.2
#
#      FFMC  DMC    DC  ISI  BUI  FWI    Classes
# 120  47.4  2.9   7.7  0.3    3  0.1  not fire
# ...

# %%
df.drop([122,123,124],axis=0, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)
df.iloc[120:130, :]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 120  29     9  2012          26  80  16   1.8  47.4  2.9   7.7  0.3     3
# 121  30     9  2012          25  78  14   1.4    45  1.9   7.5  0.2   2.4
# 122   1     6  2012          32  71  12   0.7  57.1  2.5   8.2  0.6   2.8
# 123   2     6  2012          30  73  13     4  55.7  2.7   7.8  0.6   2.9
# 124   3     6  2012          29  80  14     2  48.7  2.2   7.6  0.3   2.6
# 125   4     6  2012          30  64  14     0  79.4  5.2  15.4  2.2   5.6
# 126   5     6  2012          32  60  14   0.2  77.1    6  17.6  1.8   6.5
# 127   6     6  2012          35  54  11   0.1  83.7  8.4  26.3  3.1   9.3
# 128   7     6  2012          35  44  17   0.2  85.6  9.9  28.9  5.4  10.7
# 129   8     6  2012          28  51  17   1.3  71.4  7.7   7.4  1.5   7.3
#
#      FWI    Classes
# 120  0.1  not fire
# 121  0.1  not fire
# 122  0.2  not fire
# 123  0.2  not fire
# 124  0.1  not fire
# 125    1  not fire
# ...

# %%
df.isna().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# dtype: int64

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df.rename(columns={' RH':'RH', ' Ws':'Ws', 'Rain ':'Rain','Classes ':'Classes'},inplace=True)

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
df.loc[165,'FWI']=df.loc[165,'FWI'].replace('fire   ', '10.4')

# %%
df.loc[165,'DC']=df.loc[165,'DC'].replace('14.6 9', '14.6')

# %%
df['Classes']=df['Classes'].fillna('fire')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Classes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-51fc78e92297> in <cell line: 1>()
# ----> 1 df['Classes']=df['Classes'].fillna('fire')
#
# ...

# %%
df.isna().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# dtype: int64

# %%
for i in df.columns:
  if i!='Classes':
    df[i]=df[i].astype('float64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-97e861787a96> in <cell line: 1>()
#       1 for i in df.columns:
#       2   if i!='Classes':
# ----> 3     df[i]=df[i].astype('float64')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    float64
#  1   month        244 non-null    float64
#  2   year         244 non-null    float64
#  3   Temperature  244 non-null    float64
#  4   RH           244 non-null    float64
#  5   Ws           244 non-null    float64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
#  13  Classes      243 non-null    object
# dtypes: float64(13), object(1)
# memory usage: 26.8+ KB

# %%
df['Classes']=df['Classes'].str.strip()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Classes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-6855281dab32> in <cell line: 1>()
# ----> 1 df['Classes']=df['Classes'].str.strip()
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    float64
#  1   month        244 non-null    float64
#  2   year         244 non-null    float64
#  3   Temperature  244 non-null    float64
#  4   RH           244 non-null    float64
#  5   Ws           244 non-null    float64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
#  13  Classes      243 non-null    object
# dtypes: float64(13), object(1)
# memory usage: 26.8+ KB

# %%
df
# Out:
#       day  month    year  Temperature    RH    Ws  Rain  FFMC   DMC    DC  \
# 0     1.0    6.0  2012.0         29.0  57.0  18.0   0.0  65.7   3.4   7.6
# 1     2.0    6.0  2012.0         29.0  61.0  13.0   1.3  64.4   4.1   7.6
# 2     3.0    6.0  2012.0         26.0  82.0  22.0  13.1  47.1   2.5   7.1
# 3     4.0    6.0  2012.0         25.0  89.0  13.0   2.5  28.6   1.3   6.9
# 4     5.0    6.0  2012.0         27.0  77.0  16.0   0.0  64.8   3.0  14.2
# ..    ...    ...     ...          ...   ...   ...   ...   ...   ...   ...
# 239  26.0    9.0  2012.0         30.0  65.0  14.0   0.0  85.4  16.0  44.5
# 240  27.0    9.0  2012.0         28.0  87.0  15.0   4.4  41.1   6.5   8.0
# 241  28.0    9.0  2012.0         27.0  87.0  29.0   0.5  45.9   3.5   7.9
# 242  29.0    9.0  2012.0         24.0  54.0  18.0   0.1  79.7   4.3  15.2
# 243  30.0    9.0  2012.0         24.0  64.0  15.0   0.2  67.3   3.8  16.5
#
#      ISI   BUI  FWI     Classes
# 0    1.3   3.4  0.5   not fire
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-d636af083392> in <cell line: 2>()
#       1 plt.figure(figsize=(10,10))
# ----> 2 sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
# ...
